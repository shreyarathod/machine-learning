# %% [markdown]
# # **Imports**

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import random
import pickle

from nltk.tokenize import RegexpTokenizer

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Activation
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.losses import categorical_crossentropy
from tensorflow.keras.metrics import Accuracy
from tensorflow.keras.models import load_model

# %% [markdown]
# # **Read csv and extract relevant text**

# %%
text_df = pd.read_csv('fake_or_real_news.csv')

# %%
text_df
# Out:
#          id                                              title  \
# 0      8476                       You Can Smell Hillary’s Fear
# 1     10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2      3608        Kerry to go to Paris in gesture of sympathy
# 3     10142  Bernie supporters on Twitter erupt in anger ag...
# 4       875   The Battle of New York: Why This Primary Matters
# ...     ...                                                ...
# 6330   4490  State Department says it can't find emails fro...
# 6331   8062  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...
# 6332   8622  Anti-Trump Protesters Are Tools of the Oligarc...
# 6333   4021  In Ethiopia, Obama seeks progress on peace, se...
# 6334   4330  Jeb Bush Is Suddenly Attacking Trump. Here's W...
#
#                                                    text label
# 0     Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1     Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2     U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3     — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4     It's primary day in New York and front-runners...  REAL
# ...                                                 ...   ...
# 6330  The State Department told the Republican Natio...  REAL
# 6331  The ‘P’ in PBS Should Stand for ‘Plutocratic’ ...  FAKE
# 6332   Anti-Trump Protesters Are Tools of the Oligar...  FAKE
# 6333  ADDIS ABABA, Ethiopia —President Obama convene...  REAL
# 6334  Jeb Bush Is Suddenly Attacking Trump. Here's W...  REAL
#
# [6335 rows x 4 columns]

# %%
text =  list(text_df.text.values) ##list of all text values from csv

# %%
joined_text = (" ").join(text) ##all list elements joined together with space in btwn

# %%
partial_text = joined_text[:100000] ##taking only first 100000 characters from text body

# %% [markdown]
# # **Tokenising Words**

# %%
tokenizer = RegexpTokenizer(r'\w+') #initialising object of regexptokenizer class(splits words where words consists of letters, numbers and underscores)

# %%
tokens = tokenizer.tokenize(partial_text.lower())

# %%
unique_tokens = np.unique(tokens) ##removing duplicates

# %%
unique_tokens
# Out:
# array(['0', '000', '1', ..., 'zarif', 'zero', 'zhou'], dtype='<U18')

# %% [markdown]
# # **Mapping tokens to index.**

# %%
token_with_index = {token : index for index,token in enumerate(unique_tokens)}

# %%
token_with_index
# Out:
# {'0': 0,
#  '000': 1,
#  '1': 2,
#  '10': 3,
#  '100': 4,
#  '106': 5,
#  '10th': 6,
#  '11': 7,
#  '12': 8,
#  '12pm': 9,
#  '13': 10,
#  '14': 11,
#  '15': 12,
#  '16': 13,
#  '160': 14,
#  '17': 15,
#  '187': 16,
#  '19': 17,
#  '1939': 18,
#  '1960': 19,
#  '197': 20,
#  '1971': 21,
#  '1972': 22,
#  '1983': 23,
#  '1984': 24,
#  '1985': 25,
#  '1990s': 26,
#  '1992': 27,
#  '1994': 28,
#  '1996': 29,
#  '1998': 30,
#  '1999': 31,
#  '2': 32,
#  '20': 33,
#  '200': 34,
#  '2000': 35,
#  '20001': 36,
#  '2001': 37,
#  '2002': 38,
#  '2003': 39,
#  '2004': 40,
#  '2006': 41,
#  '2007': 42,
#  '2008': 43,
#  '2009': 44,
#  '2010': 45,
#  '2011': 46,
#  '2012': 47,
#  '2013': 48,
#  '2014': 49,
#  '2015': 50,
#  '2016': 51,
#  '2020': 52,
#  '21': 53,
#  '2117': 54,
#  '21st': 55,
#  '21wire': 56,
#  '22': 57,
#  '227': 58,
#  '23': 59,
#  '24': 60,
#  '241': 61,
#  '27': 62,
#  '2nd': 63,
#  '3': 64,
#  '30': 65,
#  '300': 66,
#  '31': 67,
#  '33': 68,
#  '3pm': 69,
#  '4': 70,
#  '40': 71,
#  '400': 72,
#  '42': 73,
#  '49': 74,
#  '5': 75,
#  '50': 76,
#  '500': 77,
#  '51': 78,
#  '52': 79,
#  '57': 80,
#  '5pm': 81,
#  '6': 82,
#  '60': 83,
#  '64': 84,
#  '650': 85,
#  '7': 86,
#  '70': 87,
#  '73': 88,
#  '8': 89,
#  '80': 90,
#  '8pm': 91,
#  '9': 92,
#  '92': 93,
#  '94': 94,
#  '95': 95,
#  '98': 96,
#  '9am': 97,
#  'a': 98,
#  'aa': 99,
#  'abc': 100,
#  'abcpolitics': 101,
#  'abedin': 102,
#  'abilities': 103,
#  'ability': 104,
#  'abject': 105,
#  'ablaze': 106,
#  'able': 107,
#  'aboard': 108,
#  'abolishing': 109,
#  'abortion': 110,
#  'about': 111,
#  'aboutface': 112,
#  'abroad': 113,
#  'absolutely': 114,
#  'absurd': 115,
#  'abu': 116,
#  'abuses': 117,
#  'abut': 118,
#  'academic': 119,
#  'accept': 120,
#  'accepted': 121,
#  'accepts': 122,
#  'access': 123,
#  'according': 124,
#  'account': 125,
#  'accountability': 126,
#  'accurate': 127,
#  'accused': 128,
#  'accusing': 129,
#  'achieve': 130,
#  'acknowledge': 131,
#  'acknowledged': 132,
#  'acknowledges': 133,
#  'acr': 134,
#  'across': 135,
#  'act': 136,
#  'acting': 137,
#  'action': 138,
#  'activist': 139,
#  'activities': 140,
#  'acts': 141,
#  'actually': 142,
#  'ad': 143,
#  'adamant': 144,
#  'add': 145,
#  'added': 146,
#  'adding': 147,
#  'addition': 148,
#  'address': 149,
#  'addressed': 150,
#  'addresses': 151,
#  'administration': 152,
#  'admission': 153,
#  'admits': 154,
#  'admitting': 155,
#  'adopting': 156,
#  'ads': 157,
#  'advance': 158,
#  'advantage': 159,
#  'advocated': 160,
#  'advocates': 161,
#  'advocating': 162,
#  'affairs': 163,
#  'affiliates': 164,
#  'affiliation': 165,
#  'affordable': 166,
#  'afghanistan': 167,
#  'afl': 168,
#  'afraid': 169,
#  'after': 170,
#  'aftermath': 171,
#  'afternoon': 172,
#  'again': 173,
#  'against': 174,
#  'age': 175,
#  'agency': 176,
#  'agents': 177,
#  'ago': 178,
#  'agree': 179,
#  'agreeing': 180,
#  'agreement': 181,
#  'agreements': 182,
#  'ahead': 183,
#  'aide': 184,
#  'aides': 185,
#  'aimed': 186,
#  'aiming': 187,
#  'air': 188,
#  'aircraft': 189,
#  'airport': 190,
#  'al': 191,
#  'alan': 192,
#  'alarm': 193,
#  'alaska': 194,
#  'album': 195,
#  'alex': 196,
#  'alexandra': 197,
#  'ali': 198,
#  'alice': 199,
#  'aligned': 200,
#  'alive': 201,
#  'all': 202,
#  'allegations': 203,
#  'allegiance': 204,
#  'allies': 205,
#  'allow': 206,
#  'allowed': 207,
#  'allowing': 208,
#  'allows': 209,
#  'allusion': 210,
#  'almost': 211,
#  'alone': 212,
#  'along': 213,
#  'already': 214,
#  'also': 215,
#  'alt': 216,
#  'although': 217,
#  'always': 218,
#  'am': 219,
#  'amazing': 220,
#  'ambassador': 221,
#  'amendment': 222,
#  'amendments': 223,
#  'america': 224,
#  'american': 225,
#  'americans': 226,
#  'amid': 227,
#  'among': 228,
#  'amongst': 229,
#  'amount': 230,
#  'an': 231,
#  'ana': 232,
#  'analyses': 233,
#  'analysis': 234,
#  'ananavarro': 235,
#  'ancestral': 236,
#  'and': 237,
#  'angela': 238,
#  'angry': 239,
#  'angus': 240,
#  'ann': 241,
#  'annexed': 242,
#  'anniversary': 243,
#  'announced': 244,
#  'anointed': 245,
#  'anonymity': 246,
#  'another': 247,
#  'answer': 248,
#  'anthony': 249,
#  'anti': 250,
#  'anticipation': 251,
#  'any': 252,
#  'anymore': 253,
#  'anyone': 254,
#  'anything': 255,
#  'anyway': 256,
#  'anywhere': 257,
#  'apart': 258,
#  'apartment': 259,
#  'apolitical': 260,
#  'appeals': 261,
#  'appear': 262,
#  'appearance': 263,
#  'appeared': 264,
#  'appearing': 265,
#  'appeaser': 266,
#  'apple': 267,
#  'application': 268,
#  'applications': 269,
#  'appointed': 270,
#  'appointment': 271,
#  'approach': 272,
#  'approaching': 273,
#  'appropriate': 274,
#  'approval': 275,
#  'approved': 276,
#  'approving': 277,
#  'april': 278,
#  'arabia': 279,
#  'archive': 280,
#  'are': 281,
#  'aren': 282,
#  'argued': 283,
#  'argument': 284,
#  'arizona': 285,
#  'arm': 286,
#  'armed': 287,
#  'army': 288,
#  'around': 289,
#  'arranged': 290,
#  'arrangement': 291,
#  'arrival': 292,
#  'arrivals': 293,
#  'arrive': 294,
#  'arrived': 295,
#  'arrives': 296,
#  'arrogant': 297,
#  'art': 298,
#  'article': 299,
#  'articles': 300,
#  'artist': 301,
#  'as': 302,
#  'ascension': 303,
#  'aside': 304,
#  'ask': 305,
#  'asked': 306,
#  'aspect': 307,
#  'aspiring': 308,
#  'assassinations': 309,
#  'assault': 310,
#  'assaulting': 311,
#  'assaults': 312,
#  'assertions': 313,
#  'assertive': 314,
#  'assess': 315,
#  'assistant': 316,
#  'associated': 317,
#  'associates': 318,
#  'associations': 319,
#  'assume': 320,
#  'assured': 321,
#  'at': 322,
#  'attack': 323,
#  'attacked': 324,
#  'attacking': 325,
#  'attacks': 326,
#  'attained': 327,
#  'attempt': 328,
#  'attempting': 329,
#  'attempts': 330,
#  'attend': 331,
#  'attended': 332,
#  'attendees': 333,
#  'attending': 334,
#  'attention': 335,
#  'attitude': 336,
#  'attorney': 337,
#  'attracted': 338,
#  'attribute': 339,
#  'audience': 340,
#  'auditorium': 341,
#  'august': 342,
#  'austin': 343,
#  'author': 344,
#  'authoritatively': 345,
#  'authorities': 346,
#  'authority': 347,
#  'authorize': 348,
#  'authors': 349,
#  'autocratic': 350,
#  'avenue': 351,
#  'average': 352,
#  'avoided': 353,
#  'avoiding': 354,
#  'award': 355,
#  'aware': 356,
#  'awareness': 357,
#  'away': 358,
#  'awesome': 359,
#  'awkward': 360,
#  'awkwardly': 361,
#  'awoke': 362,
#  'ayatollah': 363,
#  'ayotte': 364,
#  'b': 365,
#  'back': 366,
#  'backed': 367,
#  'backers': 368,
#  'backlogs': 369,
#  'bad': 370,
#  'badly': 371,
#  'balcony': 372,
#  'ballot': 373,
#  'balloting': 374,
#  'ban': 375,
#  'barack': 376,
#  'barakat': 377,
#  'barbara': 378,
#  'bare': 379,
#  'barely': 380,
#  'barriers': 381,
#  'base': 382,
#  'based': 383,
#  'basis': 384,
#  'basketball': 385,
#  'batch': 386,
#  'bathroom': 387,
#  'battle': 388,
#  'baylee': 389,
#  'be': 390,
#  'beamed': 391,
#  'beat': 392,
#  'beating': 393,
#  'beautiful': 394,
#  'became': 395,
#  'because': 396,
#  'become': 397,
#  'becomes': 398,
#  'becoming': 399,
#  'bed': 400,
#  'beds': 401,
#  'been': 402,
#  'before': 403,
#  'befriending': 404,
#  'began': 405,
#  'begin': 406,
#  'beginning': 407,
#  'begun': 408,
#  'behalf': 409,
#  'behave': 410,
#  'behavior': 411,
#  'behind': 412,
#  'beijing': 413,
#  'being': 414,
#  'belief': 415,
#  'believe': 416,
#  'believed': 417,
#  'believes': 418,
#  'believing': 419,
#  'belongs': 420,
#  'beltway': 421,
#  'benefits': 422,
#  'benjamin': 423,
#  'bernie': 424,
#  'berniesteachers': 425,
#  'beside': 426,
#  'best': 427,
#  'better': 428,
#  'between': 429,
#  'beyond': 430,
#  'biden': 431,
#  'big': 432,
#  'bigger': 433,
#  'biggest': 434,
#  'bigotry': 435,
#  'bigots': 436,
#  'bilingual': 437,
#  'bill': 438,
#  'billionaire': 439,
#  'billions': 440,
#  'bind': 441,
#  'bipartisan': 442,
#  'bit': 443,
#  'biting': 444,
#  'bizarre': 445,
#  'black': 446,
#  'blame': 447,
#  'blamed': 448,
#  'blanket': 449,
#  'blast': 450,
#  'bleeding': 451,
#  'blessings': 452,
#  'blocks': 453,
#  'bloomberg': 454,
#  'blow': 455,
#  'blowing': 456,
#  'board': 457,
#  'boardroom': 458,
#  'boardrooms': 459,
#  'boards': 460,
#  'boast': 461,
#  'boat': 462,
#  'bob': 463,
#  'body': 464,
#  'boiler': 465,
#  'bold': 466,
#  'boldly': 467,
#  'bomb': 468,
#  'book': 469,
#  'books': 470,
#  'boos': 471,
#  'booster': 472,
#  'boosting': 473,
#  'boots': 474,
#  'born': 475,
#  'borough': 476,
#  'boss': 477,
#  'boston': 478,
#  'both': 479,
#  'bottom': 480,
#  'boy': 481,
#  'boyfriend': 482,
#  'bragged': 483,
#  'bragman': 484,
#  'branch': 485,
#  'brand': 486,
#  'bratton': 487,
#  'brave': 488,
#  'break': 489,
#  'breaking': 490,
#  'breaks': 491,
#  'breathing': 492,
#  'breeds': 493,
#  'breeze': 494,
#  'breezy': 495,
#  'breitbart': 496,
#  'brew': 497,
#  'bribery': 498,
#  'bridge': 499,
#  'briefing': 500,
#  'briefings': 501,
#  'bring': 502,
#  'bringing': 503,
#  'brings': 504,
#  'britain': 505,
#  'british': 506,
#  'broadcast': 507,
#  'broadcasting': 508,
#  'broke': 509,
#  'broker': 510,
#  'brought': 511,
#  'brunch': 512,
#  'brunswick': 513,
#  'brushed': 514,
#  'build': 515,
#  'building': 516,
#  'bulgaria': 517,
#  'bullied': 518,
#  'bullies': 519,
#  'bullying': 520,
#  'bunker': 521,
#  'bureau': 522,
#  'buried': 523,
#  'burning': 524,
#  'bush': 525,
#  'business': 526,
#  'businesses': 527,
#  'but': 528,
#  'buzzed': 529,
#  'by': 530,
#  'cable': 531,
#  'california': 532,
#  'call': 533,
#  'called': 534,
#  'calling': 535,
#  'came': 536,
#  'camel': 537,
#  'camera': 538,
#  'camp': 539,
#  'campaign': 540,
#  'campaigns': 541,
#  'can': 542,
#  'canceled': 543,
#  'candidate': 544,
#  'candidates': 545,
#  'cannot': 546,
#  'cantwell': 547,
#  'capital': 548,
#  'capitulate': 549,
#  'caps': 550,
#  'capture': 551,
#  'card': 552,
#  'cards': 553,
#  'care': 554,
#  'career': 555,
#  'careers': 556,
#  'carolina': 557,
#  'carpet': 558,
#  'carried': 559,
#  'carry': 560,
#  'carrying': 561,
#  'cartwright': 562,
#  'carville': 563,
#  'case': 564,
#  'castro': 565,
#  'catalyst': 566,
#  'catch': 567,
#  'catholic': 568,
#  'catholics': 569,
#  'caucus': 570,
#  'caucuses': 571,
#  'caught': 572,
#  'caused': 573,
#  'cavuto': 574,
#  'cedar': 575,
#  'center': 576,
#  'centers': 577,
#  'central': 578,
#  'centrifuge': 579,
#  'centrifuges': 580,
#  'century': 581,
#  'ceo': 582,
#  'ceremonial': 583,
#  'ceremony': 584,
#  'certain': 585,
#  'certainly': 586,
#  'chair': 587,
#  'chairman': 588,
#  'challenge': 589,
#  'challenger': 590,
#  'chamber': 591,
#  'chambers': 592,
#  'champ': 593,
#  'championed': 594,
#  'chance': 595,
#  'chancellor': 596,
#  'chances': 597,
#  'change': 598,
#  'changed': 599,
#  'changes': 600,
#  'channel': 601,
#  'chant': 602,
#  'chanted': 603,
#  'chanting': 604,
#  'chants': 605,
#  'chapel': 606,
#  'characterized': 607,
#  'charge': 608,
#  'charges': 609,
#  'charismatic': 610,
#  'charred': 611,
#  'chart': 612,
#  'charting': 613,
#  'charts': 614,
#  'chat': 615,
#  'check': 616,
#  'checker': 617,
#  'cheek': 618,
#  'cheer': 619,
#  'chelsea': 620,
#  'cherry': 621,
#  'chest': 622,
#  'chief': 623,
#  'child': 624,
#  'childhood': 625,
#  'childish': 626,
#  'children': 627,
#  'chili': 628,
#  'chilling': 629,
#  'chilly': 630,
#  'china': 631,
#  'choice': 632,
#  'choose': 633,
#  'chord': 634,
#  'chorus': 635,
#  'chose': 636,
#  'chowder': 637,
#  'chris': 638,
#  'christian': 639,
#  'christians': 640,
#  'chuck': 641,
#  'cigi': 642,
#  'cio': 643,
#  'circle': 644,
#  'circulate': 645,
#  'circulated': 646,
#  'circumstances': 647,
#  'cite': 648,
#  'cited': 649,
#  'cites': 650,
#  'citizens': 651,
#  'city': 652,
#  'civilians': 653,
#  'civilizations': 654,
#  'claim': 655,
#  'claimed': 656,
#  'claiming': 657,
#  'claims': 658,
#  'claire': 659,
#  'clam': 660,
#  'clash': 661,
#  'class': 662,
#  'classic': 663,
#  'classified': 664,
#  'classmate': 665,
#  'classmates': 666,
#  'classroom': 667,
#  'clear': 668,
#  'clearly': 669,
#  'cleveland': 670,
#  'click': 671,
#  'clinch': 672,
#  'clinton': 673,
#  'clintons': 674,
#  'clintonworld': 675,
#  'close': 676,
#  'closed': 677,
#  'closely': 678,
#  'closeness': 679,
#  'closer': 680,
#  'closest': 681,
#  'closing': 682,
#  'clutching': 683,
#  'cnn': 684,
#  'co': 685,
#  'coalition': 686,
#  'coast': 687,
#  'cobb': 688,
#  'cognizant': 689,
#  'collaboration': 690,
#  'collaborative': 691,
#  'collapsed': 692,
#  'collars': 693,
#  'colleagues': 694,
#  'college': 695,
#  'colleges': 696,
#  'collegial': 697,
#  'collins': 698,
#  'colorado': 699,
#  'column': 700,
#  'columnist': 701,
#  'com': 702,
#  'coma': 703,
#  'combat': 704,
#  'combating': 705,
#  'combative': 706,
#  'combined': 707,
#  'come': 708,
#  'comeback': 709,
#  'comes': 710,
#  'comey': 711,
#  'comfortable': 712,
#  'coming': 713,
#  'commanded': 714,
#  'commander': 715,
#  'comment': 716,
#  'comments': 717,
#  'commission': 718,
#  'commissioner': 719,
#  'commitment': 720,
#  'commitments': 721,
#  'committee': 722,
#  'committees': 723,
#  'committing': 724,
#  'common': 725,
#  'commonality': 726,
#  'commotion': 727,
#  'communities': 728,
#  'community': 729,
#  'companies': 730,
#  'compared': 731,
#  'compete': 732,
#  'competitive': 733,
#  'complete': 734,
#  'completed': 735,
#  'completely': 736,
#  'complex': 737,
#  'compliment': 738,
#  'comprehensive': 739,
#  'compromise': 740,
#  'computer': 741,
#  'concern': 742,
#  'concerns': 743,
#  'concessions': 744,
#  'conclusion': 745,
#  'condemned': 746,
#  'condition': 747,
#  'condoleezza': 748,
#  'condos': 749,
#  'conduct': 750,
#  'conference': 751,
#  'confidence': 752,
#  'confident': 753,
#  'confidential': 754,
#  'confront': 755,
#  'congress': 756,
#  'congressional': 757,
#  'congresswoman': 758,
#  'connection': 759,
#  'connections': 760,
#  'consensus': 761,
#  'conservative': 762,
#  'consider': 763,
#  'considered': 764,
#  'consistently': 765,
#  'conspiracies': 766,
#  'conspiracy': 767,
#  'constitute': 768,
#  'constituted': 769,
#  'constrain': 770,
#  'contacted': 771,
#  'contain': 772,
#  'contemplating': 773,
#  'content': 774,
#  'contentious': 775,
#  'contest': 776,
#  'contested': 777,
#  'contests': 778,
#  'continue': 779,
#  'continues': 780,
#  'contrary': 781,
#  'contrast': 782,
#  'contributed': 783,
#  'contributor': 784,
#  'control': 785,
#  'controlled': 786,
#  'controversial': 787,
#  'controversy': 788,
#  'convention': 789,
#  'conversation': 790,
#  'conversations': 791,
#  'converted': 792,
#  'conviction': 793,
#  'convoluted': 794,
#  'cook': 795,
#  'cooperation': 796,
#  'cooperative': 797,
#  'coordinating': 798,
#  'cops': 799,
#  'copyright': 800,
#  'corker': 801,
#  'corner': 802,
#  'cornyn': 803,
#  'corporate': 804,
#  'corrected': 805,
#  'corridor': 806,
#  'corruption': 807,
#  'cosponsors': 808,
#  'costs': 809,
#  'could': 810,
#  'couldn': 811,
#  'council': 812,
#  'councilwoman': 813,
#  'count': 814,
#  'counterpart': 815,
#  'counterparts': 816,
#  'counting': 817,
#  'countless': 818,
#  'countries': 819,
#  'country': 820,
#  'countrymen': 821,
#  'couple': 822,
#  'courage': 823,
#  'course': 824,
#  'court': 825,
#  'courtyard': 826,
#  'cover': 827,
#  'covers': 828,
#  'covert': 829,
#  'cowardice': 830,
#  'coy': 831,
#  'cracked': 832,
#  'cravenly': 833,
#  'crazy': 834,
#  'created': 835,
#  'creating': 836,
#  'creation': 837,
#  'creative': 838,
#  'credibility': 839,
#  'credit': 840,
#  'credited': 841,
#  'crew': 842,
#  'cried': 843,
#  'crime': 844,
#  'crimes': 845,
#  'criminal': 846,
#  'crippling': 847,
#  'crisscrossing': 848,
#  'critical': 849,
#  'criticism': 850,
#  'criticize': 851,
#  'criticized': 852,
#  'crowd': 853,
#  'crown': 854,
#  'crucial': 855,
#  'cruz': 856,
#  'crystal': 857,
#  'cub': 858,
#  'cuba': 859,
#  'culinary': 860,
#  'cultural': 861,
#  'culture': 862,
#  'cunning': 863,
#  'current': 864,
#  'currently': 865,
#  'cuts': 866,
#  'cycle': 867,
#  'czech': 868,
#  'czechoslovakia': 869,
#  'd': 870,
#  'dad': 871,
#  'dallas': 872,
#  'damaging': 873,
#  'dame': 874,
#  'damn': 875,
#  'damned': 876,
#  'danger': 877,
#  'dangerous': 878,
#  'dangers': 879,
#  'dangled': 880,
#  'daniel': 881,
#  'daniele': 882,
#  'dark': 883,
#  'darkest': 884,
#  'data': 885,
#  'database': 886,
#  'date': 887,
#  'dates': 888,
#  'daughter': 889,
#  'day': 890,
#  'days': 891,
#  'dead': 892,
#  'deadline': 893,
#  'deah': 894,
#  'deal': 895,
#  'death': 896,
#  'debate': 897,
#  'debbie': 898,
#  'debi': 899,
#  'dec': 900,
#  'decade': 901,
#  'decades': 902,
#  'decadeslong': 903,
#  'december': 904,
#  'decide': 905,
#  'decided': 906,
#  'decides': 907,
#  'deciding': 908,
#  'decision': 909,
#  'decisionmaking': 910,
#  'declare': 911,
#  'declared': 912,
#  'declaring': 913,
#  'declined': 914,
#  'decried': 915,
#  'decry': 916,
#  'dedicated': 917,
#  'deem': 918,
#  'deep': 919,
#  'deeper': 920,
#  'deeply': 921,
#  'defamation': 922,
#  'defang': 923,
#  'defeat': 924,
#  'defend': 925,
#  'defended': 926,
#  'defending': 927,
#  'defense': 928,
#  'define': 929,
#  'degradation': 930,
#  'delegate': 931,
#  'delegates': 932,
#  'delegation': 933,
#  'deliberate': 934,
#  'delicious': 935,
#  'deliver': 936,
#  'delivered': 937,
#  'dem': 938,
#  'demagoguery': 939,
#  'demand': 940,
#  'demanding': 941,
#  'democracy': 942,
#  'democrat': 943,
#  'democratic': 944,
#  'democrats': 945,
#  'demons': 946,
#  'demonstrated': 947,
#  'dems': 948,
#  'denial': 949,
#  'denominator': 950,
#  'deny': 951,
#  'department': 952,
#  'departure': 953,
#  'depending': 954,
#  'derail': 955,
#  'des': 956,
#  'described': 957,
#  'desecrated': 958,
#  'desert': 959,
#  'deserved': 960,
#  'design': 961,
#  'desire': 962,
#  'despair': 963,
#  'desperate': 964,
#  'desperately': 965,
#  'desperation': 966,
#  'despite': 967,
#  'destination': 968,
#  'destroy': 969,
#  'details': 970,
#  'determine': 971,
#  'determines': 972,
#  'devastating': 973,
#  'develop': 974,
#  'developer': 975,
#  'developers': 976,
#  'development': 977,
#  'dialing': 978,
#  'did': 979,
#  'didn': 980,
#  'die': 981,
#  'died': 982,
#  'difference': 983,
#  'differences': 984,
#  'different': 985,
#  'differently': 986,
#  'difficult': 987,
#  'digg': 988,
#  'dimension': 989,
#  'dinner': 990,
#  'dinners': 991,
#  'dionne': 992,
#  'diplomatic': 993,
#  'direct': 994,
#  'direction': 995,
#  'directive': 996,
#  'directly': 997,
#  'director': 998,
#  'disability': 999,
#  ...}

# %% [markdown]
# # **Splitting into X and Y**

# %%
n_words = int(10)
input_words = []
next_words = []

for i in range(len(unique_tokens) - n_words ):
  input_words.append(unique_tokens[i:i+n_words])
  next_words.append(unique_tokens[i+n_words])

# %%
##setting dimensions for X and y
X = np.zeros((len(input_words), n_words , len(unique_tokens)), dtype = 'bool')
y = np.zeros((len(next_words), len(unique_tokens)), dtype='bool')

# %%
##adding values to X and Y
for i,words in enumerate(input_words):
  for j,word in enumerate(words):
    X[i,j, token_with_index[word]] = 1
  y[i, token_with_index[next_words[i]]] = 1

# %%
X, y
# Out:
# (array([[[ True, False, False, ..., False, False, False],
#          [False,  True, False, ..., False, False, False],
#          [False, False,  True, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         [[False,  True, False, ..., False, False, False],
#          [False, False,  True, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         [[False, False,  True, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         ...,
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False]],
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ...,  True, False, False]],
#
#         [[False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ..., False, False, False],
#          ...,
#          [False, False, False, ..., False, False, False],
#          [False, False, False, ...,  True, False, False],
#          [False, False, False, ..., False,  True, False]]]),
#  array([[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ...,  True, False, False],
#         [False, False, False, ..., False,  True, False],
#         [False, False, False, ..., False, False,  True]]))

# %% [markdown]
# # **Model Compilation and Training**

# %%
X = X.astype('float32')
y = y.astype('float32')

# %%
model = tf.keras.Sequential(
    [
        # tf.keras.layers.LSTM(128, input_shape=(n_words, len(unique_tokens)) , return_sequences = True),
        # tf.keras.layers.LSTM(128),
        # tf.keras.layers.Dense(len(unique_tokens)),
        # tf.keras.layers.Activation('softmax')


        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64, return_sequences=True)),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Dense(len(unique_tokens), activation='softmax')
    ]
)


##Bidirectional LSTMs are used to provide both future and past sequential context
##Dropout layer to prevent overfitting - (drops neurons that might not be contributing to the output effectively)

# %%
model.compile(loss = 'categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X , y, batch_size = 64, epochs = 35 , shuffle=True)
# Out:
# Epoch 1/35
# 58/58 [==============================] - 13s 18ms/step - loss: 8.2274 - accuracy: 0.0000e+00
# Epoch 2/35
# 58/58 [==============================] - 1s 16ms/step - loss: 8.2101 - accuracy: 2.7049e-04
# Epoch 3/35
# 58/58 [==============================] - 1s 17ms/step - loss: 8.2170 - accuracy: 2.7049e-04
# Epoch 4/35
# 58/58 [==============================] - 1s 17ms/step - loss: 8.1811 - accuracy: 0.0000e+00
# Epoch 5/35
# 58/58 [==============================] - 1s 16ms/step - loss: 8.0199 - accuracy: 2.7049e-04
# Epoch 6/35
# 58/58 [==============================] - 1s 16ms/step - loss: 7.6636 - accuracy: 0.0022
# Epoch 7/35
# 58/58 [==============================] - 1s 17ms/step - loss: 7.1143 - accuracy: 0.0073
# Epoch 8/35
# 58/58 [==============================] - 1s 23ms/step - loss: 6.5304 - accuracy: 0.0319
# Epoch 9/35
# 58/58 [==============================] - 2s 26ms/step - loss: 5.9698 - accuracy: 0.1004
# Epoch 10/35
# 58/58 [==============================] - 1s 16ms/step - loss: 5.4548 - accuracy: 0.2291
# Epoch 11/35
# 58/58 [==============================] - 1s 16ms/step - loss: 4.9724 - accuracy: 0.3722
# Epoch 12/35
# 58/58 [==============================] - 1s 16ms/step - loss: 4.5283 - accuracy: 0.5101
# Epoch 13/35
# 58/58 [==============================] - 1s 16ms/step - loss: 4.1164 - accuracy: 0.6251
# Epoch 14/35
# 58/58 [==============================] - 1s 16ms/step - loss: 3.7334 - accuracy: 0.7317
# Epoch 15/35
# 58/58 [==============================] - 1s 16ms/step - loss: 3.3606 - accuracy: 0.8009
# Epoch 16/35
# 58/58 [==============================] - 1s 16ms/step - loss: 3.0117 - accuracy: 0.8447
# Epoch 17/35
# 58/58 [==============================] - 1s 16ms/step - loss: 2.6900 - accuracy: 0.8848
# Epoch 18/35
# 58/58 [==============================] - 1s 16ms/step - loss: 2.4056 - accuracy: 0.9080
# Epoch 19/35
# 58/58 [==============================] - 1s 16ms/step - loss: 2.1316 - accuracy: 0.9308
# Epoch 20/35
# 58/58 [==============================] - 1s 20ms/step - loss: 1.8922 - accuracy: 0.9413
# Epoch 21/35
# 58/58 [==============================] - 1s 25ms/step - loss: 1.6701 - accuracy: 0.9554
# Epoch 22/35
# 58/58 [==============================] - 1s 21ms/step - loss: 1.4822 - accuracy: 0.9624
# Epoch 23/35
# 58/58 [==============================] - 1s 16ms/step - loss: 1.3041 - accuracy: 0.9778
# Epoch 24/35
# 58/58 [==============================] - 1s 16ms/step - loss: 1.1423 - accuracy: 0.9775
# Epoch 25/35
# 58/58 [==============================] - 1s 16ms/step - loss: 1.0051 - accuracy: 0.9843
# Epoch 26/35
# 58/58 [==============================] - 1s 16ms/step - loss: 0.8871 - accuracy: 0.9878
# Epoch 27/35
# 58/58 [==============================] - 1s 16ms/step - loss: 0.7841 - accuracy: 0.9913
# Epoch 28/35
# 58/58 [==============================] - 1s 16ms/step - loss: 0.6951 - accuracy: 0.9954
# Epoch 29/35
# 58/58 [==============================] - 1s 16ms/step - loss: 0.6204 - accuracy: 0.9957
# Epoch 30/35
# 58/58 [==============================] - 1s 16ms/step - loss: 0.5564 - accuracy: 0.9959
# Epoch 31/35
# 58/58 [==============================] - 1s 16ms/step - loss: 0.5023 - accuracy: 0.9965
# Epoch 32/35
# 58/58 [==============================] - 1s 16ms/step - loss: 0.4521 - accuracy: 0.9970
# Epoch 33/35
# 58/58 [==============================] - 1s 23ms/step - loss: 0.4134 - accuracy: 0.9984
# Epoch 34/35
# 58/58 [==============================] - 1s 24ms/step - loss: 0.3709 - accuracy: 0.9995
# Epoch 35/35
# 58/58 [==============================] - 1s 18ms/step - loss: 0.3383 - accuracy: 0.9992

# %%
model.save('nextword.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model = load_model('nextword.h5')

# %% [markdown]
# # **Model Predictions**

# %%
def predict_next_word(input_words, n_best):
  input_words = input_words.lower().split()
  X=np.zeros((1,int(n_words),len(unique_tokens)))
  for i,word in enumerate(input_words):
    X[0,i,token_with_index[word]] = 1;
  predictions = model.predict(X)[0]
  return np.argpartition(predictions, -n_best)[-n_best:]

# %%
def generate_text(input_words, text_len, choice=3):
  words = input_words.lower().split()
  current = 0;
  for i in range(text_len):
    sub_seq = " ".join(tokenizer.tokenize(" ".join(words))[current:current+n_words])
    try:
      word = unique_tokens[random.choice(predict_next_word(sub_seq, choice))]
    except:
      word = random.choice(unique_tokens)
    words.append(word)
    current = current +1

  return " ".join(words)

# %%
possible = predict_next_word('He came back at the house with his family at', 5)
# Out:
# 1/1 [==============================] - 0s 22ms/step

# %%
for i in possible:
  print(unique_tokens[i])
# Out:
# stories
# museum
# peddle
# ending
# kindertransports
